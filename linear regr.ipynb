# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import scipy
import sklearn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_excel(r'C:\Users\Kristine\.ipynb_checkpoints\table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.xls', header = 4)

# %%
df1.head()
# Out:
#                        City  Population  Violent\ncrime  \
# 0             Adams Village      1861.0             0.0
# 1  Addison Town and Village      2577.0             3.0
# 2             Akron Village      2846.0             3.0
# 3                    Albany     97956.0           791.0
# 4            Albion Village      6388.0            23.0
#
#    Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# 0                                     0.0                           NaN
# 1                                     0.0                           NaN
# 2                                     0.0                           NaN
# 3                                     8.0                           NaN
# 4                                     0.0                           NaN
#
#    Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault  Property\ncrime  \
# 0                          0.0      0.0                  0.0             12.0
# 1                          0.0      0.0                  3.0             24.0
# 2                          0.0      0.0                  3.0             16.0
# 3                         30.0    227.0                526.0           4090.0
# 4                          3.0      4.0                 16.0            223.0
#
#    Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft  Arson3   Population2
# 0       2.0             10.0                    0.0     0.0  3.463321e+06
# 1       3.0             20.0                    1.0     0.0  6.640929e+06
# 2       1.0             15.0                    0.0     0.0  8.099716e+06
# 3     705.0           3243.0                  142.0     NaN  9.595378e+09
# 4      53.0            165.0                    5.0     NaN  4.080654e+07

# %%
df1['Population2_float'] = df1['Population'] * df1['Population']
df1['Population2'] = df1['Population'] * df1['Population']

# %%
df1.Population2 = df1.Population2.apply(lambda value:"{:,}".format(value))

# %%
df1.head()
# Out:
#                        City  Population  Violent\ncrime  \
# 0             Adams Village      1861.0             0.0
# 1  Addison Town and Village      2577.0             3.0
# 2             Akron Village      2846.0             3.0
# 3                    Albany     97956.0           791.0
# 4            Albion Village      6388.0            23.0
#
#    Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# 0                                     0.0                           NaN
# 1                                     0.0                           NaN
# 2                                     0.0                           NaN
# 3                                     8.0                           NaN
# 4                                     0.0                           NaN
#
#    Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault  Property\ncrime  \
# 0                          0.0      0.0                  0.0             12.0
# 1                          0.0      0.0                  3.0             24.0
# 2                          0.0      0.0                  3.0             16.0
# 3                         30.0    227.0                526.0           4090.0
# 4                          3.0      4.0                 16.0            223.0
#
#    Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft  Arson3      Population2  \
# 0       2.0             10.0                    0.0     0.0      3,463,321.0
# 1       3.0             20.0                    1.0     0.0      6,640,929.0
# 2       1.0             15.0                    0.0     0.0      8,099,716.0
# 3     705.0           3243.0                  142.0     NaN  9,595,377,936.0
# 4      53.0            165.0                    5.0     NaN     40,806,544.0
#
#    Population2_float
# 0       3.463321e+06
# 1       6.640929e+06
# 2       8.099716e+06
# 3       9.595378e+09
# 4       4.080654e+07

# %%
df1['Murder_cat'] = df1['Murder and\nnonnegligent\nmanslaughter'].apply(lambda x: 1 if x > 0 else 0)
df1['Robbery_cat'] = df1['Robbery'].apply(lambda x: 1 if x > 0 else 0)

# %%
df1.head()
# Out:
#                        City  Population  Violent\ncrime  \
# 0             Adams Village      1861.0             0.0
# 1  Addison Town and Village      2577.0             3.0
# 2             Akron Village      2846.0             3.0
# 3                    Albany     97956.0           791.0
# 4            Albion Village      6388.0            23.0
#
#    Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# 0                                     0.0                           NaN
# 1                                     0.0                           NaN
# 2                                     0.0                           NaN
# 3                                     8.0                           NaN
# 4                                     0.0                           NaN
#
#    Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault  Property\ncrime  \
# 0                          0.0      0.0                  0.0             12.0
# 1                          0.0      0.0                  3.0             24.0
# 2                          0.0      0.0                  3.0             16.0
# 3                         30.0    227.0                526.0           4090.0
# 4                          3.0      4.0                 16.0            223.0
#
#    Burglary  Larceny-\ntheft  Motor\nvehicle\ntheft  Arson3      Population2  \
# 0       2.0             10.0                    0.0     0.0      3,463,321.0
# 1       3.0             20.0                    1.0     0.0      6,640,929.0
# 2       1.0             15.0                    0.0     0.0      8,099,716.0
# 3     705.0           3243.0                  142.0     NaN  9,595,377,936.0
# 4      53.0            165.0                    5.0     NaN     40,806,544.0
#
#    Population2_float  Murder_cat  Robbery_cat
# 0       3.463321e+06           0            0
# 1       6.640929e+06           0            0
# 2       8.099716e+06           0            0
# 3       9.595378e+09           1            1
# 4       4.080654e+07           0            1
